# %%
from TFRE import TFRE 
import numpy as np

# %%
n = 100
p = 400
X = np.random.normal(0,1,size=(n,p))
beta =  np.append([1.5,-1.25,1,-0.75,0.5],np.zeros(p-5))
y = X.dot(beta) + np.random.normal(0,1,n)

# %%
obj = TFRE()
obj.fit(X,y,eta_list=np.arange(0.09,0.51,0.03))
obj.coef("1st")[:10]
# Out:
# array([-0.03857345,  1.03759586, -0.54021073,  0.70328196, -0.3025841 ,
#         0.        ,  0.        ,  0.        ,  0.        ,  0.        ])

# %%
obj.coef("2nd")[:10]
# Out:
# array([-0.08230346,  1.51108575, -0.77512336,  1.04087465, -0.52236789,
#         0.20509697,  0.        ,  0.        ,  0.        ,  0.        ])

# %%
fig = obj.plot()

# %%
newX = np.random.normal(0,1,size=(10,p))
obj.predict(newX,"2nd")
# Out:
# array([ 0.46749922,  1.54731038, -6.92640292,  1.33077392,  1.93677265,
#        -1.79084016, -2.56021896, -1.41153942, -4.9066248 ,  3.58563597])
