# %%
from TFRE import TFRE 
import numpy as np

# %%
n = 100
p = 400
X = np.random.normal(0,1,size=(n,p))
beta =  np.append([1.5,-1.25,1,-0.75,0.5],np.zeros(p-5))
y = X.dot(beta) + np.random.normal(0,1,n)

# %%
obj = TFRE()
obj.fit(X,y,eta_list=np.arange(0.09,0.51,0.03))
obj.coef("1st")[:10]
# Out:
# array([ 0.05317785,  0.95798465, -0.95446442,  0.75982081, -0.26879279,
#         0.02917157,  0.        ,  0.        ,  0.        ,  0.        ])

# %%
obj.coef("2nd")[:10]
# Out:
# array([ 0.08156135,  1.50389774, -1.55487476,  1.15364031, -0.56241393,
#         0.25090776,  0.        ,  0.        ,  0.        ,  0.        ])

# %%
fig = obj.plot()

# %%
newX = np.random.normal(0,1,size=(10,p))
obj.predict(newX,"2nd")
# Out:
# array([-1.65289454, -3.98859715, -4.1137867 , -1.59081106, -1.64073413,
#        -2.05649   ,  0.93580258, -0.59615412, -0.3913797 ,  2.2933792 ])
